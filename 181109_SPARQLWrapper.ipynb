# %% [markdown]
# ## Method (I)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pdx

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
# From https://www.wikidata.org/wiki/Wikidata:SPARQL_query_service/queries/examples#Cats
sparql.setQuery("""
SELECT DISTINCT ?doid ?item ?label ?wpLang
 
WHERE {
   # ?item wdt:P699 ?doid ;
         rdfs:label ?label ;
         rdfs:label ?english .
   # ?article schema:about ?item ;
            schema:inLanguage ?wpLang .
   FILTER (lang(?label) = ?wpLang)
   FILTER (lang(?english) = "en")
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['doid.value', 'item.value', 'label.value', 'wpLang.value']]
# Out:
#          doid.value                               item.value  \
# 0         DOID:4184   http://www.wikidata.org/entity/Q819207
# 1         DOID:4184   http://www.wikidata.org/entity/Q819207
# 2         DOID:4184   http://www.wikidata.org/entity/Q819207
# 3         DOID:4184   http://www.wikidata.org/entity/Q819207
# 4         DOID:4184   http://www.wikidata.org/entity/Q819207
# 5         DOID:4184   http://www.wikidata.org/entity/Q819207
# 6         DOID:4184   http://www.wikidata.org/entity/Q819207
# 7         DOID:4184   http://www.wikidata.org/entity/Q819207
# 8         DOID:2377     http://www.wikidata.org/entity/Q8277
# 9         DOID:2377     http://www.wikidata.org/entity/Q8277
# 10        DOID:2750   http://www.wikidata.org/entity/Q829150
# 11        DOID:2750   http://www.wikidata.org/entity/Q829150
# 12        DOID:2750   http://www.wikidata.org/entity/Q829150
# 13        DOID:2750   http://www.wikidata.org/entity/Q829150
# 14        DOID:2750   http://www.wikidata.org/entity/Q829150
# 15        DOID:2750   http://www.wikidata.org/entity/Q829150
# 16        DOID:2750   http://www.wikidata.org/entity/Q829150
# 17        DOID:2750   http://www.wikidata.org/entity/Q829150
# 18        DOID:2377     http://www.wikidata.org/entity/Q8277
# 19        DOID:2377     http://www.wikidata.org/entity/Q8277
# 20       DOID:11729   http://www.wikidata.org/entity/Q201989
# 21       DOID:11729   http://www.wikidata.org/entity/Q201989
# 22        DOID:2377     http://www.wikidata.org/entity/Q8277
# 23        DOID:2377     http://www.wikidata.org/entity/Q8277
# 24        DOID:2377     http://www.wikidata.org/entity/Q8277
# 25       DOID:11729   http://www.wikidata.org/entity/Q201989
# 26       DOID:11729   http://www.wikidata.org/entity/Q201989
# 27        DOID:4184   http://www.wikidata.org/entity/Q819207
# 28       DOID:10080   http://www.wikidata.org/entity/Q842169
# 29        DOID:9201   http://www.wikidata.org/entity/Q848371
# ...             ...                                      ...
# 47079     DOID:3616  http://www.wikidata.org/entity/Q4763273
# 47080      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47081    DOID:12072  http://www.wikidata.org/entity/Q4362791
# 47082    DOID:12072  http://www.wikidata.org/entity/Q4362791
# 47083    DOID:12072  http://www.wikidata.org/entity/Q4362791
# 47084    DOID:12072  http://www.wikidata.org/entity/Q4362791
# 47085    DOID:13507  http://www.wikidata.org/entity/Q3678252
# 47086    DOID:13507  http://www.wikidata.org/entity/Q3678252
# 47087    DOID:13507  http://www.wikidata.org/entity/Q3678252
# 47088    DOID:10208  http://www.wikidata.org/entity/Q5104526
# 47089     DOID:3463  http://www.wikidata.org/entity/Q4959796
# 47090     DOID:3463  http://www.wikidata.org/entity/Q4959796
# 47091     DOID:3463  http://www.wikidata.org/entity/Q4959796
# 47092     DOID:3463  http://www.wikidata.org/entity/Q4959796
# 47093     DOID:3463  http://www.wikidata.org/entity/Q4959796
# 47094  DOID:0050670  http://www.wikidata.org/entity/Q4812914
# 47095      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47096      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47097      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47098      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47099      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47100      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47101  DOID:0080085  http://www.wikidata.org/entity/Q5160446
# 47102  DOID:0080085  http://www.wikidata.org/entity/Q5160446
# 47103      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47104      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47105      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47106      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47107      DOID:986  http://www.wikidata.org/entity/Q5075435
# 47108  DOID:0060061  http://www.wikidata.org/entity/Q5196687
#
#                                    label.value wpLang.value
# 0                      قصور جارات الدرق الكاذب           ar
# 1                  Pseudohypoparathyreoidismus           de
# 2                     pseudohypoparathyroidism           en
# 3                     pseudohipoparatiroidismo           es
# 4                 کم‌کاری کاذب غده پاراتیروئید           fa
# 5                    Pseudohipoparatireoidizam           hr
# 6                                  偽性副甲状腺機能低下症           ja
# 7                                    거짓부갑상샘저하증           ko
# 8                                   تصلب متعدد           ar
# 9                          Esclerosis múltiple          ast
# 10                         malaltia d'Andersen           ca
# 11                             Morbus Andersen           de
# 12                 glycogen storage disease IV           en
# 13                      Enfermedad de Andersen           es
# 14                          گلیکوژنوز نوع چهار           fa
# 15                            Choroba Andersen           pl
# 16                           Болезнь Андерсена           ru
# 17                            Хвороба Андерсен           uk
# 18                           Multipla skleroza           bs
# 19                          esclerosi múltiple           ca
# 20                                    داء لايم           ar
# 21                          enfermedad de Lyme           es
# 22                        মাল্টিপল স্ক্লেরোসিস           bn
# 23                             Dağınıq skleroz           az
# 24                        Множествена склероза           bg
# 25                           Enfermedá de Lyme          ast
# 26                                    Барэліёз           be
# 27           rzekoma niedoczynność przytarczyc           pl
# 28                                داء المكفنات           ar
# 29                                  liquen pla           ca
# ...                                        ...          ...
# 47079                                    血管脂肪腫           ja
# 47080                          alopecia areata           it
# 47081                             Пілараспазма           be
# 47082                              Пилороспазм           ky
# 47083                            Pilorospazmas           lt
# 47084                              Пилороспазм           ru
# 47085                               trigonitis           en
# 47086                               trigonitis           es
# 47087                                trigonite           pt
# 47088                         chondroid lipoma           en
# 47089                                 स्तन रोग           hi
# 47090                              ਛਾਤੀ ਦੇ ਰੋਗ           pa
# 47091                                 ସ୍ତନ ରୋଗ           or
# 47092                                 ಸ್ತನ ರೋಗ           kn
# 47093                                 स्तन रोग          mai
# 47094                           شلل دماغي رنحي           ar
# 47095                      Łysienie plackowate           pl
# 47096                          Alopecia areata           nl
# 47097                          alopecia areata           nb
# 47098                          ଆଲୋପେସିଆ ଏରିଆଟା           or
# 47099                          ਐਲੋਪੀਸੀਆ ਐਰੀਆਟਾ           pa
# 47100                          Alopecia Areata           sq
# 47101              Kongenitale Onychodysplasie           de
# 47102  nonsyndromic congenital nail disorder 7           en
# 47103                          Alopecia areata           ms
# 47104                          alopecia areata           sv
# 47105                          అలోపీసీయా ఎరేటా           te
# 47106                           Alopesi areata           tr
# 47107                                       圓禿           zh
# 47108               لمفوما جلدية تائية الخلايا           ar
#
# [47109 rows x 4 columns]

# %%
language = 'english'
abbre = 'en'

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# specify the double "{}" for format()
sparql.setQuery("""
SELECT DISTINCT ?doid ?item ?label ?wpLang
WHERE {{
   # ?item wdt:P699 ?doid ;
         rdfs:label ?label ;
         rdfs:label ?{0} .
   # ?article schema:about ?item ;
            schema:inLanguage ?wpLang .
   FILTER (lang(?label) = ?wpLang)
   FILTER (lang(?{0}) = "{1}")
}}
""".format(language, abbre))

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['doid.value', 'item.value', 'label.value', 'wpLang.value']]
# Out:
#          doid.value                              item.value  \
# 0         DOID:4184  http://www.wikidata.org/entity/Q819207
# 1         DOID:4184  http://www.wikidata.org/entity/Q819207
# 2         DOID:4184  http://www.wikidata.org/entity/Q819207
# 3         DOID:4184  http://www.wikidata.org/entity/Q819207
# 4         DOID:4184  http://www.wikidata.org/entity/Q819207
# 5         DOID:4184  http://www.wikidata.org/entity/Q819207
# 6         DOID:4184  http://www.wikidata.org/entity/Q819207
# 7         DOID:4184  http://www.wikidata.org/entity/Q819207
# 8         DOID:2750  http://www.wikidata.org/entity/Q829150
# 9         DOID:2750  http://www.wikidata.org/entity/Q829150
# 10        DOID:2750  http://www.wikidata.org/entity/Q829150
# 11        DOID:2750  http://www.wikidata.org/entity/Q829150
# 12        DOID:2750  http://www.wikidata.org/entity/Q829150
# 13        DOID:2750  http://www.wikidata.org/entity/Q829150
# 14        DOID:2750  http://www.wikidata.org/entity/Q829150
# 15        DOID:2750  http://www.wikidata.org/entity/Q829150
# 16        DOID:4184  http://www.wikidata.org/entity/Q819207
# 17       DOID:10080  http://www.wikidata.org/entity/Q842169
# 18       DOID:10080  http://www.wikidata.org/entity/Q842169
# 19       DOID:10080  http://www.wikidata.org/entity/Q842169
# 20       DOID:10080  http://www.wikidata.org/entity/Q842169
# 21       DOID:10080  http://www.wikidata.org/entity/Q842169
# 22       DOID:10080  http://www.wikidata.org/entity/Q842169
# 23       DOID:10080  http://www.wikidata.org/entity/Q842169
# 24       DOID:10080  http://www.wikidata.org/entity/Q842169
# 25        DOID:2377    http://www.wikidata.org/entity/Q8277
# 26        DOID:2377    http://www.wikidata.org/entity/Q8277
# 27        DOID:2377    http://www.wikidata.org/entity/Q8277
# 28        DOID:2377    http://www.wikidata.org/entity/Q8277
# 29       DOID:11729  http://www.wikidata.org/entity/Q201989
# ...             ...                                     ...
# 47076     DOID:2862  http://www.wikidata.org/entity/Q848343
# 47077     DOID:2862  http://www.wikidata.org/entity/Q848343
# 47078     DOID:2862  http://www.wikidata.org/entity/Q848343
# 47079    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47080    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47081    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47082    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47083     DOID:2862  http://www.wikidata.org/entity/Q848343
# 47084    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47085    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47086    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47087    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47088    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47089    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47090    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47091    DOID:11396  http://www.wikidata.org/entity/Q857667
# 47092      DOID:255  http://www.wikidata.org/entity/Q861028
# 47093      DOID:255  http://www.wikidata.org/entity/Q861028
# 47094      DOID:255  http://www.wikidata.org/entity/Q861028
# 47095      DOID:255  http://www.wikidata.org/entity/Q861028
# 47096      DOID:255  http://www.wikidata.org/entity/Q861028
# 47097     DOID:3829  http://www.wikidata.org/entity/Q864296
# 47098     DOID:3829  http://www.wikidata.org/entity/Q864296
# 47099     DOID:3829  http://www.wikidata.org/entity/Q864296
# 47100  DOID:0060562  http://www.wikidata.org/entity/Q881480
# 47101  DOID:0070003  http://www.wikidata.org/entity/Q882077
# 47102     DOID:1441  http://www.wikidata.org/entity/Q899726
# 47103     DOID:1441  http://www.wikidata.org/entity/Q899726
# 47104     DOID:1441  http://www.wikidata.org/entity/Q899726
# 47105     DOID:1441  http://www.wikidata.org/entity/Q899726
#
#                                         label.value wpLang.value
# 0                           قصور جارات الدرق الكاذب           ar
# 1                       Pseudohypoparathyreoidismus           de
# 2                          pseudohypoparathyroidism           en
# 3                          pseudohipoparatiroidismo           es
# 4                      کم‌کاری کاذب غده پاراتیروئید           fa
# 5                         Pseudohipoparatireoidizam           hr
# 6                                       偽性副甲状腺機能低下症           ja
# 7                                         거짓부갑상샘저하증           ko
# 8                               malaltia d'Andersen           ca
# 9                                   Morbus Andersen           de
# 10                      glycogen storage disease IV           en
# 11                           Enfermedad de Andersen           es
# 12                               گلیکوژنوز نوع چهار           fa
# 13                                 Choroba Andersen           pl
# 14                                Болезнь Андерсена           ru
# 15                                 Хвороба Андерсен           uk
# 16                rzekoma niedoczynność przytarczyc           pl
# 17                                     داء المكفنات           ar
# 18                                       Sparganose           de
# 19                                      sparganosis           en
# 20                                     Esparganosis           es
# 21                                       sparganose           fr
# 22                                           스파르가눔증           ko
# 23                                        Спарганоз           ru
# 24                                        Спарганоз           uk
# 25                                  Dağınıq skleroz           az
# 26                             Множествена склероза           bg
# 27                                       تصلب متعدد           ar
# 28                              Esclerosis múltiple          ast
# 29                                         داء لايم           ar
# ...                                             ...          ...
# 47076  Manjak enzima glukoza-6-fosfat dehidrogenaze           sh
# 47077                        โรคพร่องเอนไซม์ G-6-PD           th
# 47078                                           蠶豆病          yue
# 47079                                    وذمة الرئة           ar
# 47080                             Akutni edem pluća           bs
# 47081                                edema pulmonar           ca
# 47082                                   plicní edém           cs
# 47083           ଗ୍ଲୁକୋଜ-୬-ଫସଫେଟ ଡିହାଇଡ୍ରୋଜେନେଜ ଅଭାବ           or
# 47084                                    Lungenödem           de
# 47085                               pulmonary edema           en
# 47086                                edema pulmonar           es
# 47087                              biriketako edema           eu
# 47088                                       ادم ریه           fa
# 47089                                  keuhkoödeema           fi
# 47090                          œdème aigu du poumon           fr
# 47091                                    בצקת ריאות           he
# 47092                                     Hämangiom           de
# 47093                                ورم وعائي دموي           ar
# 47094                                    Гемангіёма           be
# 47095                                    hemangioma           ca
# 47096                                     hemangiom           cs
# 47097                            ورم الغدة النخامية           ar
# 47098                            adenoma d'hipòfisi           ca
# 47099                               adenom hypofýzy           cs
# 47100                   Bland-White-Garland-Syndrom           de
# 47101                                       Blastom           de
# 47102                               رنح نخاعي مخيخي           ar
# 47103                    Спінацэрэберальная атаксія           be
# 47104                      Спиноцеребеларна атаксия           bg
# 47105                     atàxia espinocerebel·losa           ca
#
# [47106 rows x 4 columns]

# %% [markdown]
# ## Method (II)

# %%
import pandas as pd
import json
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
def get_sparql_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %%
wds = "https://query.wikidata.org/sparql"

# %%
rq = """
SELECT DISTINCT ?doid ?item ?label ?wpLang
 
WHERE {
   # ?item wdt:P699 ?doid ;
         rdfs:label ?label ;
         rdfs:label ?english .
   # ?article schema:about ?item ;
            schema:inLanguage ?wpLang .
   FILTER (lang(?label) = ?wpLang)
   FILTER (lang(?english) = "en")
}
"""

# %%
df = get_sparql_dataframe(wds, rq)

# %%
df.head()
# Out:
#         doid                                    item  \
# 0  DOID:4184  http://www.wikidata.org/entity/Q819207
# 1  DOID:4184  http://www.wikidata.org/entity/Q819207
# 2  DOID:4184  http://www.wikidata.org/entity/Q819207
# 3  DOID:4184  http://www.wikidata.org/entity/Q819207
# 4  DOID:4184  http://www.wikidata.org/entity/Q819207
#
#                           label wpLang
# 0       قصور جارات الدرق الكاذب     ar
# 1   Pseudohypoparathyreoidismus     de
# 2      pseudohypoparathyroidism     en
# 3      pseudohipoparatiroidismo     es
# 4  کم‌کاری کاذب غده پاراتیروئید     fa

# %%
df.describe()
# Out:
#             doid                                   item  label wpLang
# count      47109                                  47109  47109  47109
# unique      3588                                   3564  41320    236
# top     DOID:635  http://www.wikidata.org/entity/Q79793   AIDS     en
# freq         157                                    202     38   3245

# %%
df['label'].value_counts()[:10]
# Out:
# AIDS               38
# Malaria            23
# Ebola              21
# SARS               19
# meningitis         18
# Hepatitis A        18
# Kuru               17
# Vitiligo           15
# Gastroenteritis    15
# Kwashiorkor        14
# Name: label, dtype: int64
