# %%
from tqdm import tqdm, tqdm_notebook

# %%
import pandas as pd
import numpy as np
import json
from wikidataintegrator import wdi_core
import matplotlib.pyplot as plt

query = """
SELECT * WHERE {
{SELECT ?item (COUNT(DISTINCT ?wdLang) as ?WDTranslations) (GROUP_CONCAT(DISTINCT ?wdLang) as ?wdlanguages ) WHERE {
   # ?item wdt:P699 ?doid ;
         rdfs:label ?label .
   BIND (lang(?label) AS ?wdLang)
}
GROUP BY ?item ?itemLabel
}

{SELECT ?item ?itemLabel (COUNT(DISTINCT ?wpLang) as ?WPTranslations) (GROUP_CONCAT(DISTINCT ?wpLang) as ?wplanguages ) WHERE {
   # ?item wdt:P699 ?doid .
   # ?article schema:about ?item ;
            schema:inLanguage ?wpLang .
   # BIND (lang(?label) AS ?lang)
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?item ?itemLabel

}
#FILTER (?WDTranslations != ?WPTranslations)
BIND ((?WDTranslations - ?WPTranslations) as ?difference )
}
ORDER BY DESC(?WDTranslations)
"""

df = wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe=True)

# %%
df.head()
# Out:
#    WDTranslations  WPTranslations  difference  \
# 0             172             158          14
# 1             158             138          20
# 2             157             144          13
# 3             149             146           3
# 4             147             140           7
#
#                                     item     itemLabel  \
# 0  http://www.wikidata.org/entity/Q12199          AIDS
# 1  http://www.wikidata.org/entity/Q12136       disease
# 2  http://www.wikidata.org/entity/Q12078        cancer
# 3  http://www.wikidata.org/entity/Q12156       malaria
# 4  http://www.wikidata.org/entity/Q12204  tuberculosis
#
#                                          wdlanguages  \
# 0  su sv sw ta te tg th tk tl tr ts tt tum uk ur ...
# 1  es ru de fr pt it ca fi hu ka lb sv en nb nl g...
# 2  rw de id af am an ar arc arz as ast az azb ba ...
# 3  da ig af ak an ar arz as ast az ba be be-taras...
# 4  ar sh zh-hant fa uz szl vi pl af am an arz as ...
#
#                                          wplanguages
# 0  af gsw am an ar arz as ast az ba sgs be-tarask...
# 1  ht hu hy ia id ilo io is it ja jam jv ka kk kn...
# 2  af gsw am an ar arc arz as ast az azb ba sgs b...
# 3  af ak gsw an ar arz as ast az ba sgs be-tarask...
# 4  nn nb nv oc or pa pl pnb ps pt qu ro ru rue sa...

# %%
df["WDTranslations"].astype(str).astype(int).mean()
# Out:
# 16.759731167740128

# %%
df["WPTranslations"].astype(str).astype(int).mean()
# Out:
# 13.248669840380845

# %%
# top 10 disease terms with translations available through Wikidata
df[["itemLabel","WDTranslations", "WPTranslations", "difference"]].head(10)
# Out:
#              itemLabel  WDTranslations  WPTranslations  difference
# 0                 AIDS             172             158          14
# 1              disease             158             138          20
# 2               cancer             157             144          13
# 3              malaria             149             146           3
# 4         tuberculosis             147             140           7
# 5    diabetes mellitus             138             133           5
# 6  Ebola virus disease             132             124           8
# 7            influenza             131             125           6
# 8              cholera             128             121           7
# 9  Alzheimer's disease             124             107          17

# %%
query = """
SELECT DISTINCT ?doid ?item ?label ?wpLang
 
WHERE {
   # ?item wdt:P699 ?doid ;
         rdfs:label ?label ;
         rdfs:label ?english .
         
   # ?article schema:about ?item ;
            schema:inLanguage ?wpLang .
   FILTER (lang(?label) = ?wpLang)
   FILTER (lang(?english) = "en")
}
"""
df = wdi_core.WDItemEngine.execute_sparql_query(query, as_dataframe=True)

# %%
df.head()
# Out:
#         doid                                    item  \
# 0  DOID:4184  http://www.wikidata.org/entity/Q819207
# 1  DOID:4184  http://www.wikidata.org/entity/Q819207
# 2  DOID:4184  http://www.wikidata.org/entity/Q819207
# 3  DOID:4184  http://www.wikidata.org/entity/Q819207
# 4  DOID:4184  http://www.wikidata.org/entity/Q819207
#
#                           label wpLang
# 0       قصور جارات الدرق الكاذب     ar
# 1   Pseudohypoparathyreoidismus     de
# 2      pseudohypoparathyroidism     en
# 3      pseudohipoparatiroidismo     es
# 4  کم‌کاری کاذب غده پاراتیروئید     fa

# %%
df2 = pd.DataFrame()
gb = df.groupby("doid")
for n in gb:
  s = n[1][['label', 'wpLang']].set_index("wpLang").T
  s = s.groupby(s.columns, axis=1).agg(lambda x: '|'.join(x.values))
  s['ID'] = n[0]
  df2 = df2.append(s)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df2.head()
# Out:
#                  ID  ace   af   ak   am   an  ang               ar  arc  arz  \
# label  DOID:0001816  NaN  NaN  NaN  NaN  NaN  NaN   ساركومة وعائية  NaN  NaN
# label  DOID:0002116  NaN  NaN  NaN  NaN  NaN  NaN           الظفرة  NaN  NaN
# label  DOID:0014667  NaN  NaN  NaN  NaN  NaN  NaN  اضطراب استقلابي  NaN  NaN
# label  DOID:0040002  NaN  NaN  NaN  NaN  NaN  NaN              NaN  NaN  NaN
# label  DOID:0050011  NaN  NaN  NaN  NaN  NaN  NaN              NaN  NaN  NaN
#
#       ...   wuu   xh  xmf   yi   yo  yue   za  zea    zh   zu
# label ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# label ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  翼状胬肉  NaN
# label ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  代謝疾病  NaN
# label ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# label ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 238 columns]

# %%
df2 = df2.set_index("ID")

# %%
df2.loc['DOID:9351']
# Out:
# ace                        NaN
# af                Suikersiekte
# ak                         NaN
# am                     ስኳር በሽታ
# an           Diabetis mellitus
# ang                        NaN
# ar                      السكري
# arc                        NaN
# arz                  مرض السكر
# as                বহুমুত্ৰ ৰোগ
# ast                   Diabetes
# av                         NaN
# ay                         NaN
# az              Şəkərli diabet
# azb                      دیابت
# ba               Шәкәр диабеты
# bar                        NaN
# bcl                        NaN
# be              цукровы дыябет
# be-tarask       цукровы дыябэт
# bg              Захарен диабет
# bho                        NaN
# bjn                        NaN
# bm                         NaN
# bn                বহুমূত্র রোগ
# bo                         NaN
# bpy                 ডায়াবেটিস
# br                      Diabet
# bs           Diabetes mellitus
# bxr            Саахарай диабет
#                    ...
# tpi                        NaN
# tr                     Diyabet
# ts                         NaN
# tt                Шикәр авыруы
# tum                        NaN
# tyv                        NaN
# udm                        NaN
# ug                         NaN
# uk             цукровий діабет
# ur                     ذیابیطس
# uz               Qandli diabet
# ve                         NaN
# vec                        NaN
# vep                        NaN
# vi                  Tiểu đường
# vls                        NaN
# vro                        NaN
# wa                         NaN
# war          Diabetes mellitus
# wo                         NaN
# wuu                        糖尿病
# xh                         NaN
# xmf           შანქარიშ დიაბეტი
# yi                  צוקערקרענק
# yo                         NaN
# yue                         糖尿
# za                         NaN
# zea                        NaN
# zh                         糖尿病
# zu                         NaN
# Name: DOID:9351, Length: 237, dtype: object

# %%
# df2.to_csv("sdfeg.csv")
